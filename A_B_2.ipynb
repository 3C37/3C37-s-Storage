# %% [markdown]
# <a href="https://colab.research.google.com/github/3C37/3C37-s-Storage/blob/main/A_B_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## https://www.acmicpc.net/problem/15792

A, B = map(int, input().split())

m = (str(A//B)+".")
A = (A%B)*10

for i in range(1000):
    m += str(A//B)
    A = (A%B)*10
print(m)
# Out:
# 1 8
# 0....
